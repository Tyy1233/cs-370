# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %% [markdown]
# import random
# import gym
# import numpy as np
# from collections import deque
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.optimizers import Adam
#
#
# from scores.score_logger import ScoreLogger
#
# ENV_NAME = "CartPole-v1"
#
# GAMMA = 0.95
# LEARNING_RATE = 0.001
#
# MEMORY_SIZE = 1000000
# BATCH_SIZE = 20
#
# EXPLORATION_MAX = 1.0
# EXPLORATION_MIN = 0.01
# EXPLORATION_DECAY = 0.995
#
#
# class DQNSolver:
#
#     def __init__(self, observation_space, action_space):
#         self.exploration_rate = EXPLORATION_MAX
#
#         self.action_space = action_space
#         self.memory = deque(maxlen=MEMORY_SIZE)
#
#         self.model = Sequential()
#         self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
#         self.model.add(Dense(24, activation="relu"))
#         self.model.add(Dense(self.action_space, activation="linear"))
#         self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))
#
#     def remember(self, state, action, reward, next_state, done):
#         self.memory.append((state, action, reward, next_state, done))
#
#     def act(self, state):
#         if np.random.rand() < self.exploration_rate:
#             return random.randrange(self.action_space)
#         q_values = self.model.predict(state)
#         return np.argmax(q_values[0])
#
#     def experience_replay(self):
#         if len(self.memory) < BATCH_SIZE:
#             return
#         batch = random.sample(self.memory, BATCH_SIZE)
#         for state, action, reward, state_next, terminal in batch:
#             q_update = reward
#             if not terminal:
#                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#             q_values = self.model.predict(state)
#             q_values[0][action] = q_update
#             self.model.fit(state, q_values, verbose=0)
#         self.exploration_rate *= EXPLORATION_DECAY
#         self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
#
#
# def cartpole():
#     env = gym.make(ENV_NAME)
#     score_logger = ScoreLogger(ENV_NAME)
#     observation_space = env.observation_space.shape[0]
#     action_space = env.action_space.n
#     dqn_solver = DQNSolver(observation_space, action_space)
#     run = 0
#     while True:
#         run += 1
#         state = env.reset()
#         state = np.reshape(state, [1, observation_space])
#         step = 0
#         while True:
#             step += 1
#             #env.render()
#             action = dqn_solver.act(state)
#             state_next, reward, terminal, info = env.step(action)
#             reward = reward if not terminal else -reward
#             state_next = np.reshape(state_next, [1, observation_space])
#             dqn_solver.remember(state, action, reward, state_next, terminal)
#             state = state_next
#             if terminal:
#                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
#                 score_logger.add_score(step, run)
#                 break
#             dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 11
# Scores: (min: 11, avg: 11, max: 11)
#
# Run: 2, exploration: 0.9046104802746175, score: 29
# Scores: (min: 11, avg: 20, max: 29)
#
# Run: 3, exploration: 0.8307187014821328, score: 18
# Scores: (min: 11, avg: 19.333333333333332, max: 29)
#
# Run: 4, exploration: 0.7901049725470279, score: 11
# Scores: (min: 11, avg: 17.25, max: 29)
#
# Run: 5, exploration: 0.7005493475733617, score: 25
# Scores: (min: 11, avg: 18.8, max: 29)
#
# Run: 6, exploration: 0.6730128848950395, score: 9
# Scores: (min: 9, avg: 17.166666666666668, max: 29)
#
# Run: 7, exploration: 0.6242658676435396, score: 16
# Scores: (min: 9, avg: 17, max: 29)
#
# Run: 8, exploration: 0.5997278763867329, score: 9
# Scores: (min: 9, avg: 16, max: 29)
#
# Run: 9, exploration: 0.5704072587541458, score: 11
# Scores: (min: 9, avg: 15.444444444444445, max: 29)
#
# Run: 10, exploration: 0.5371084840724134, score: 13
# Scores: (min: 9, avg: 15.2, max: 29)
#
# ...

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.1  
EXPLORATION_DECAY = 0.99  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.8514577710948754, score: 36
# Scores: (min: 36, avg: 36, max: 36)
#
# Run: 2, exploration: 0.7397003733882802, score: 15
# Scores: (min: 15, avg: 25.5, max: 36)
#
# Run: 3, exploration: 0.6298236312032323, score: 17
# Scores: (min: 15, avg: 22.666666666666668, max: 36)
#
# Run: 4, exploration: 0.5471566423907612, score: 15
# Scores: (min: 15, avg: 20.75, max: 36)
#
# Run: 5, exploration: 0.48499137027416284, score: 13
# Scores: (min: 13, avg: 19.2, max: 36)
#
# Run: 6, exploration: 0.44752321376381066, score: 9
# Scores: (min: 9, avg: 17.5, max: 36)
#
# Run: 7, exploration: 0.40882017442254937, score: 10
# Scores: (min: 9, avg: 16.428571428571427, max: 36)
#
# Run: 8, exploration: 0.37346428045426927, score: 10
# Scores: (min: 9, avg: 15.625, max: 36)
#
# Run: 9, exploration: 0.334376856889913, score: 12
# Scores: (min: 9, avg: 15.222222222222221, max: 36)
#
# Run: 10, exploration: 0.29938039131233124, score: 12
# Scores: (min: 9, avg: 14.9, max: 36)
#
# ...

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %% [markdown]
# The goal of the agent is to find the best possible outcome for the action to forget the reward. The different states are a combination of position, velocity, angle and point. This allows for the possible actions of the action to change any of those variables and get closer to the goal. The RL algorithm is what is overall affected algorithm. Experience is replayed through the explanation where the score and decay can be seen. A discount factor would increase the speed in which the AI would be able to learn. The neural network uses the a algorithm to find whether the answer is correct and sees how the solution is getting closer.
#
# Beysolow, T. (2019). 3. In Applied Reinforcement Learning with python: With Openai Gym, tensorflow, and keras. essay, Apress.
# Gulli, A., &amp; Pal, S. (2017). 8. In Deep learning with keras: Implement neural networks with Keras on Theano and tensorflow. essay, Packt Publishing.
